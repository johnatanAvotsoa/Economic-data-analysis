# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import plotly.express as px

# %%
from fredapi import Fred
api_key = '579c8ff1b8d32df5a57b36a999f09f15'
Fred(api_key= api_key)
